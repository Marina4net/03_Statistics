# %% [markdown]
# # Домашняя работа №2

# %%
import numpy as np
from scipy.optimize import approx_fprime
import matplotlib.pyplot as plt
from scipy.optimize import minimize, approx_fprime, fmin, brute

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Придумайте функции со следующими свойствами (в a) b) c) область определения X любая, какая вам удобна, главное - функция с нужными свойствами):
#
# a) бесконечное количество локальных экстремумов
#
# b) 2 локальных экстремума
#
# с) 3 локальных экстремума
#
# d*) область определения функции - 1 точка

# %%
infer = [np.sin(i/10) for i in range(0, 80)] #синус - бесконечное число экстремумов
plt.plot(infer)
plt.ylabel('синусы')
plt.xlabel('числа')
# Out:
# Text(0.5, 0, 'числа')

# %%
m = np.linspace(-20, 20, 100) #два экстремума и разрыв, настройки графика неудобные
ex2 = [(i**3 - 3 * i**2 - 9 * i + 2) for i in m]
plt.plot(m, ex2)

# %%
m = [i/20 for i in range(-10, 90)] # третий порядок - три экстремума
ex3 = [(1 * i**4 - 8 * i**3 + 22*i**2 - 24 * i + 1) for i in m]
plt.plot(m, ex3)

# %%
#область определения функции точка
#График - вертикальная прямая
#пример математической записи x = 5

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Посчитайте 1-ую и 2-ую производные функции (на бумажке):
#
# $f(x) = sin^2(2x+1)$

# %% [markdown]
# первая производная
# f'(x) = 2*sin(4x+2)
#
# вторая производная
# f''(x) = 8*cos(4x+2)

# %% [markdown]
# ### Задание 3:
# Посчитайте частные производные функции в точкe
# (на бумажке или в LaTeX и на numpy):

# %% [markdown]
# $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$ в точке $(1,2)$

# %%
def func(x):
    return 2 * (x[0]**2) * (x[1]**3) + (1 / x[0]) +  (x[1]**2) * x[0] + 7

x = np.array([1, 2])

eps = np.sqrt(np.finfo(float).eps)
print(eps)
approx_fprime(x, func, [eps, eps])
# Out:
# 1.4901161193847656e-08
# array([35.00000024, 28.00000024])

# %% [markdown]
# ### Задание 4:
#
# Градиентный спуск своими руками

# %%
def f(x):
    return (x[0]**2) + (x[1]**2)

# %%
x = np.array([100, 200])
lr = 0.1

# %%
for i in range(100):
    grad = approx_fprime(x, f, epsilon=1e-5) 
    x = x - lr * grad

# %%
print("Минимум достигается в: ", x)
print("Значение функции в минимуме: ", f(x))
# Out:
# Минимум достигается в:  [-5.e-06 -5.e-06]
# Значение функции в минимуме:  4.9999999999999976e-11

# %% [markdown]
# Проверка с помощью встроенной функции scipy:

# %%
res = minimize(f, x, method='nelder-mead', options={'xtol': 1e-6, 'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 72
#          Function evaluations: 138
